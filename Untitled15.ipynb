# %% [markdown]
# <a href="https://colab.research.google.com/github/z0919648-a11y/PYTHON-PROJECT-/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CSV FILES
import pandas as pd
coffee = pd.read('./warmup-data/coffee.csv')
coffee.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3258/2842874579.py in <cell line: 0>()
#       1 #CSV FILES
#       2 import pandas as pd
# ----> 3 coffee = pd.read('./warmup-data/coffee.csv')
#       4 coffee.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
import pandas as pd

coffee = pd.read_csv("coffee.csv")
coffee.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3258/1763434017.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 coffee = pd.read_csv("coffee.csv")
#       4 coffee.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'coffee.csv'

# %%
import pandas as pd

coffee = pd.read_csv("coffee.csv")
coffee.head()
# Out:
#    Day Coffee Type  Price
# 0  Mon       Latte    350
# 1  Tue    Espresso    300
# 2  Wed  Cappuccino    400
# 3  Thu   Americano    320
# 4  Fri       Mocha    450

# %%
import pandas as pd

coffee = pd.read_csv("complete-pandas-tutorial/warmup-data/coffee.csv")
coffee.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3258/1776624139.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 coffee = pd.read_csv("complete-pandas-tutorial/warmup-data/coffee.csv")
#       4 coffee.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'complete-pandas-tutorial/warmup-data/coffee.csv'

# %%
import pandas as pd

data = {
    "Day": ["Mon", "Tue", "Wed", "Thu", "Fri"],
    "Coffee Type": ["Latte", "Espresso", "Cappuccino", "Americano", "Mocha"],
    "Price": [350, 300, 400, 320, 450]
}

coffee = pd.DataFrame(data)

coffee.to_csv("coffee.csv", index=False)

print("coffee.csv created successfully!")
coffee.head()
# Out:
# coffee.csv created successfully!
#    Day Coffee Type  Price
# 0  Mon       Latte    350
# 1  Tue    Espresso    300
# 2  Wed  Cappuccino    400
# 3  Thu   Americano    320
# 4  Fri       Mocha    450

# %%
import pandas as pd
data = {
"name" : ["ALi","Ahmed","Asia","izza","noor","zainab"],
"Roll num": [1,2,3,4,5,6],
"subject" : ["English","math","urdu","science","PK studies","math2"],
"Grade":["A","B","C","D","E","F"]
}
student_df = pd.DataFrame(data)

student_df.to_csv("student_data.csv", index=False)

print("student data.csv created successfully!")

student_df.head()
# Out:
# student data.csv created successfully!
#     name  Roll num     subject Grade
# 0    ALi         1     English     A
# 1  Ahmed         2        math     B
# 2   Asia         3        urdu     C
# 3   izza         4     science     D
# 4   noor         5  PK studies     E

# %%
import pandas as pd
df = pd.read_csv("student_data.csv")
df.columns
# Out:
# Index(['name', 'Roll num', 'subject', 'Grade'], dtype='object')

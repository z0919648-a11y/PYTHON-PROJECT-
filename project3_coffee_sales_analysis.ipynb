# %% [markdown]
# <a href="https://colab.research.google.com/github/z0919648-a11y/PYTHON-PROJECT-/blob/main/project3_coffee_sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Date":[
"2026-07-01" ,"2026-07-02","2026-07-03","2026-07-04","2026-07-05","2026-07-06","2026-07-07","2026-07-08","2026-07-09","2026-07-10"],
    "coffee type":["latte","Espresso","Mocha","Americano","cappuccino","latte","Espresso","Mocha","Americano","cappuccino"],
    "City":["Lahore","karachi","Islamabad","Multan","chakwal","Lahore","karachi","Islamabad","chakwal","Multan"],
"Price":[350,360,370 ,380,400,350,360,370,380,400],
"Quantity":[2,3,4,5,2,4,7,6,8,9],
"Payment":["card","cash","cash","card","cash","cash","card","cash","cash","card"]


}

coffee = pd.DataFrame(data)
coffee.to_csv("coffee_sales.csv", index=False)
print ("coffee")

print (coffee.head())

print (coffee.tail())

(coffee.info)

print (coffee.describe())

print(coffee["coffee type"].value_counts())

print (coffee.groupby("coffee type")["Price"].mean())

print(coffee.sort_values("Price", ascending=False))
# Out:
# coffee
#          Date coffee type       City  Price  Quantity Payment
# 0  2026-07-01       latte     Lahore    350         2    card
# 1  2026-07-02    Espresso    karachi    360         3    cash
# 2  2026-07-03       Mocha  Islamabad    370         4    cash
# 3  2026-07-04   Americano     Multan    380         5    card
# 4  2026-07-05  cappuccino    chakwal    400         2    cash
#          Date coffee type       City  Price  Quantity Payment
# 5  2026-07-06       latte     Lahore    350         4    cash
# 6  2026-07-07    Espresso    karachi    360         7    card
# 7  2026-07-08       Mocha  Islamabad    370         6    cash
# 8  2026-07-09   Americano    chakwal    380         8    cash
# 9  2026-07-10  cappuccino     Multan    400         9    card
#             Price  Quantity
# count   10.000000  10.00000
# mean   372.000000   5.00000
# std     18.135294   2.44949
# min    350.000000   2.00000
# 25%    360.000000   3.25000
# 50%    370.000000   4.50000
# ...

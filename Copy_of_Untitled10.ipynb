# %% [markdown]
# <a href="https://colab.research.google.com/github/z0919648-a11y/PYTHON-PROJECT-/blob/main/Copy_of_Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello word')
# Out:
# Hello word

# %%
import matplotlib.pyplot as plt

students = ["Ali", "Sara", "Ahmed", "Ayesha"]
marks = [85, 90, 75, 95]

plt.bar(students, marks)

plt.title("Students Marks")
plt.xlabel("Students")
plt.ylabel("Marks")

plt.show()

# %%
Matplot

# %%
print("introduction to pandas")
# Out:
# introduction to pandas

# %%
# %pip install pandas

# %%
#key data structure in pandas
# series  datafram
import pandas as pd
s = pd .Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"name": ["herry","ali" ,"ahamd"],"marks": [100,53,45]})
df =ma
# Out:
#     name  marks
# 0  herry    100
# 1    ali     53
# 2  ahamd     45

# %%
df = pd.DataFarme({"name": ["herry","ali" ,"ahamd"],"marks": [100,53,45]})

# %% [markdown]
# # New Section

# %%
import pandas as pd

pd.read_csv("student.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1996/1193036081.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 pd.read_csv("student.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

data = {
  "Name":["Ali" ,"sara","ahmed"],
  "Age" :[20,21,22] ,
  "Marks" : [85,90,78]
}
df = pd.DataFrame(data)
df.to_csv("student.csv",index=False)
print("student.csv save ho gayi")
# Out:
#   File "/tmp/ipykernel_1996/3320693568.py", line 4
#     "Name:["Ali" ,"sara',"ahmed"],
#                        ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "Ahmed"],
    "Age": [20, 21, 22],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)

df.to_csv("students.csv", index=False)
print("CSV file ban gayi!")
# Out:
# CSV file ban gayi!

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb992f3a-9bef-4b06-9e8a-d8895ed8982e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb992f3a-9bef-4b06-9e8a-d8895ed8982e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

data = {
    "Name": ["Ali", "Sara", "Ahmed"],
    "Age": [20, 21, 22]
}

df = pd.DataFrame(data)

df.to_csv("iris.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("iris.csv")
print(df)
# Out:
#     Name  Age
# 0    Ali   20
# 1   Sara   21
# 2  Ahmed   22

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df.describe()
# Out:
#         Age      Marks
# count   3.0   3.000000
# mean   21.0  84.333333
# std     1.0   6.027714
# min    20.0  78.000000
# 25%    20.5  81.500000
# 50%    21.0  85.000000
# 75%    21.5  87.500000
# max    22.0  90.000000

# %%
import pandas as pd

df = pd.read_csv("students.csv")
df.columns
# Out:
# Index(['Name', 'Age', 'Marks'], dtype='object')

# %%
import pandas as pd
df = pd.read_csv("students.csv")
df["Name"]
# Out:
# 0      Ali
# 1     Sara
# 2    Ahmed
# Name: Name, dtype: object

# %%
df.head()
# Out:
#     Name  Age
# 0    Ali   20
# 1   Sara   21
# 2  Ahmed   22

# %%
df.tail()
# Out:
#     Name  Age
# 0    Ali   20
# 1   Sara   21
# 2  Ahmed   22

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   21.0
# std     1.0
# min    20.0
# 25%    20.5
# 50%    21.0
# 75%    21.5
# max    22.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Marks   3 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 204.0+ bytes

# %% [markdown]
# # New Section

# %%
(df["Name"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10488/1858998323.py in <cell line: 0>()
# ----> 1 (df["Name"])
#
# NameError: name 'df' is not defined

# %%
(df["Age"])

# %%
import pandas as pd
pd = pd.read_csv("students.csv")
df("Name" ," Marks")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1996/3012457585.py in <cell line: 0>()
#       1 import pandas as pd
#       2 pd = pd.read_csv("students.csv")
# ----> 3 df("Name" ," Marks")
#
# TypeError: 'DataFrame' object is not callable

# %%
df.iloc[1:3]
# Out:
#     Name  Age  Marks
# 1   Sara   21     90
# 2  Ahmed   22     78

# %%
df.dropna()
# Out:
#     Name  Age  Marks
# 0    Ali   20     85
# 1   Sara   21     90
# 2  Ahmed   22     78

# %%
df.fillna(0,inplace=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1996/2964917887.py in <cell line: 0>()
# ----> 1 df.fillna(0,inplace=true)
#
# NameError: name 'true' is not defined

# %%
type(df["Name"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10488/1921506260.py in <cell line: 0>()
# ----> 1 type(df["Name"])
#
# NameError: name 'df' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_10488/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'sample_data']

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

df = pd.DataFrame(iris.data, columns=iris.feature_names)

df.to_csv("iris.csv", index=False)

print("iris.csv save ho gayi")
# Out:
# iris.csv save ho gayi

# %%
from google.colab import files

files.download("iris.csv")

# %%
import os
print(os.listdir())
# Out:
# ['.config', 'iris.csv', 'sample_data']

# %%
import pandas as pd

df = pd.read_csv("iris.csv")
print(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

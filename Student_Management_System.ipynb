# %% [markdown]
# <a href="https://colab.research.google.com/github/z0919648-a11y/PYTHON-PROJECT-/blob/main/Student_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os

filename = "students.csv"

# Create CSV file if it doesn't exist
if not os.path.isfile(filename):
    with open(filename, "w", newline="") as file:
        writer = csv.writer(file)
        writer.writerow(["Name", "Roll No", "Age"])

Student = []

while True:
    print("\n===== Student Management System =====")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Delete Student")
    print("6. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        name = input("Enter student name: ")
        roll_no = input("Enter student roll no: ")
        age = input("Enter student age: ")

        student = {
            "name": name,
            "roll_no": roll_no,
            "age": age
        }

        Student.append(student)

        with open(filename, "a", newline="") as file:
            writer = csv.writer(file)
            writer.writerow([name, roll_no, age])

        print("Student added successfully!")

    elif choice == 2:
        if len(Student) == 0:
            print("No students found!")
        else:
            for student in Student:
                print(student)

    elif choice == 3:
        search_name = input("Enter student name to search: ")
        found = False

        for student in Student:
            if student["name"].lower() == search_name.lower():
                print(student)
                found = True
                break

        if not found:
            print("Student not found!")

    elif choice == 4:
        search_name = input("Enter student name to update: ")
        found = False

        for student in Student:
            if student["name"].lower() == search_name.lower():
                student["name"] = input("Enter new name: ")
                student["roll_no"] = input("Enter new roll no: ")
                student["age"] = input("Enter new age: ")
                print("Student updated successfully!")
                found = True
                break

        if not found:
            print("Student not found!")

    elif choice == 5:
        search_name = input("Enter student name to delete: ")
        found = False

        for student in Student:
            if student["name"].lower() == search_name.lower():
                Student.remove(student)
                print("Student deleted successfully!")
                found = True
                break

        if not found:
            print("Student not found!")

    elif choice == 6:
        print("Exiting...")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your choice: 1
# Enter student name: ALI
# Enter student roll no: 21
# Enter student age: 20
# Student added successfully!
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your choice: 2
# {'name': 'ALI', 'roll_no': '21', 'age': '20'}
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your choice: 3
# Enter student name to search: ALI
# {'name': 'ALI', 'roll_no': '21', 'age': '20'}
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Delete Student
# 6. Exit
# Enter your choice: 4
# Enter student name to update: ALI
# Enter new name: AHMED
# ...
